# %%
# Load CSV Using Python Standard Library 
import csv 
import numpy
import pandas
filename = 'breast_cancer_data.csv' 
# raw_data = open(filename, 'rt' ) 
# reader = csv.reader(raw_data, delimiter=',' , quoting=csv.QUOTE_NONE) 
# x = list(reader) 
# data = numpy.array(x).astype('string' ) 
data = pandas.read_csv('breast_cancer_data.csv')
print(data.shape)
# Out:
# (300, 11)

# %%
import scipy
import numpy
import matplotlib
import pandas

# !python --version
print('scipy version: %s'%(scipy.__version__))
print('numpy version: %s'%(numpy.__version__))
print('matplotlib version: %s'%(matplotlib.__version__))
print('pandas version: %s'%(pandas.__version__))
# Out:
# scipy version: 1.0.0
# numpy version: 1.14.2
# matplotlib version: 2.1.2
# pandas version: 0.22.0
# Python 3.6.4 :: Anaconda, Inc.

# %%
# View first 20 rows 
from pandas import read_csv 
filename = "breast_cancer_data.csv" 
#names = ['Batch', 'Eng7', 'Eng8', 'Math7', 'Math8', 'Math9', 'ClassTarget'] 
data = read_csv(filename) 
peek = data.head(20)
#print(peek)
peek
# Out:
#     Unnamed: 0  Clump Thickness  Uniformity of Cell Size  \
# 0            0                5                        1
# 1            1                5                        4
# 2            2                3                        1
# 3            3                6                        8
# 4            4                4                        1
# 5            5                8                       10
# 6            6                1                        1
# 7            7                2                        1
# 8            8                2                        1
# 9            9                4                        2
# 10          10                1                        1
# 11          11                2                        1
# 12          12                5                        3
# 13          13                1                        1
# 14          14                8                        7
# 15          15                7                        4
# 16          16                4                        1
# 17          17                4                        1
# 18          18               10                        7
# 19          19                6                        1
#
#     Uniformity of Cell Shape  Marginal Adhesion    \
# 0                          1                    1
# 1                          4                    5
# 2                          1                    1
# 3                          8                    1
# 4                          1                    3
# 5                         10                    8
# 6                          1                    1
# 7                          2                    1
# 8                          1                    1
# 9                          1                    1
# 10                         1                    1
# 11                         1                    1
# 12                         3                    3
# 13                         1                    1
# 14                         5                   10
# 15                         6                    4
# 16                         1                    1
# 17                         1                    1
# 18                         7                    6
# 19                         1                    1
#
#     Single Epithelial  Cell Size  Bare Nuclei  Bland Chromatin  \
# 0                              2            1                3
# 1                              7           10                3
# 2                              2            2                3
# 3                              3            4                3
# 4                              2            1                3
# 5                              7           10                9
# 6                              2           10                3
# 7                              2            1                3
# 8                              2            1                1
# 9                              2            1                2
# 10                             1            1                3
# 11                             2            1                2
# 12                             2            3                4
# 13                             2            3                3
# 14                             7            9                5
# 15                             6            1                4
# 16                             2            1                2
# 17                             2            1                3
# 18                             4           10                4
# 19                             2            1                3
#
#     Normal Nucleoli  Mitoses  Target
# 0                 1        1       0
# 1                 2        1       0
# 2                 1        1       0
# 3                 7        1       0
# 4                 1        1       0
# 5                 7        1       1
# 6                 1        1       0
# 7                 1        1       0
# 8                 1        5       0
# 9                 1        1       0
# 10                1        1       0
# 11                1        1       0
# 12                4        1       1
# 13                1        1       0
# 14                5        4       1
# 15                3        1       1
# 16                1        1       0
# 17                1        1       0
# 18                1        2       1
# 19                1        1       0

# %%
# Data Types for Each Attribute 
from pandas import read_csv 
filename = "breast_cancer_data.csv" 
#names = ['Batch', 'Eng7', 'Eng8', 'Math7', 'Math8', 'Math9', 'ClassTarget'] 
data = read_csv(filename) 
types = data.dtypes 
#print(types)
types
# Out:
# Unnamed: 0                      int64
# Clump Thickness                 int64
# Uniformity of Cell Size         int64
# Uniformity of Cell Shape        int64
# Marginal Adhesion               int64
# Single Epithelial  Cell Size    int64
# Bare Nuclei                     int64
# Bland Chromatin                 int64
# Normal Nucleoli                 int64
# Mitoses                         int64
# Target                          int64
# dtype: object

# %%
from pandas import read_csv 
from pandas import set_option 
filename = "breast_cancer_data.csv" 
#names = ['Batch', 'Eng7', 'Eng8', 'Math7', 'Math8', 'Math9', 'ClassTarget'] 
data = read_csv(filename) 
set_option('display.width', 100) 
set_option('precision', 3) 
description = data.describe() 
#print(description)
description
# Out:
#        Unnamed: 0  Clump Thickness  Uniformity of Cell Size  Uniformity of Cell Shape  \
# count     300.000          300.000                  300.000                   300.000
# mean      149.500            4.873                    3.547                     3.717
# std        86.747            3.116                    3.133                     3.088
# min         0.000            1.000                    1.000                     1.000
# 25%        74.750            2.000                    1.000                     1.000
# 50%       149.500            5.000                    2.000                     3.000
# 75%       224.250            8.000                    5.000                     6.000
# max       299.000           10.000                   10.000                    10.000
#
#        Marginal Adhesion    Single Epithelial  Cell Size  Bare Nuclei  Bland Chromatin  \
# count              300.000                       300.000      300.000          300.000
# mean                 3.020                         3.677        4.267            3.913
# std                  2.941                         2.538        3.839            2.162
# min                  1.000                         1.000        1.000            1.000
# 25%                  1.000                         2.000        1.000            2.750
# 50%                  1.000                         2.000        2.000            3.000
# 75%                  4.000                         5.000        9.000            5.000
# max                 10.000                        10.000       10.000           10.000
#
#        Normal Nucleoli  Mitoses   Target
# count          300.000  300.000  300.000
# mean             3.470    1.873    0.457
# std              3.283    2.047    0.499
# min              1.000    1.000    0.000
# 25%              1.000    1.000    0.000
# 50%              1.000    1.000    0.000
# 75%              6.000    1.000    1.000
# max             10.000   10.000    1.000

# %%
# Class Distribution
from pandas import read_csv 
filename = "breast_cancer_data.csv" 
#names = ['Batch', 'Eng7', 'Eng8', 'Math7', 'Math8', 'Math9', 'ClassTarget'] 
data = read_csv(filename)
class_counts = data.groupby('Target').size() 
print(class_counts)
class_counts
# Out:
# Target
# 0    163
# 1    137
# dtype: int64
# Target
# 0    163
# 1    137
# dtype: int64

# %%
# Pairwise Pearson correlations 
from pandas import read_csv 
from pandas import set_option 
filename = "breast_cancer_data.csv" 
#names = ['Batch', 'Eng7', 'Eng8', 'Math7', 'Math8', 'Math9', 'ClassTarget'] 
data = read_csv(filename) 
set_option('display.width', 100) 
set_option('precision', 3) 
correlations = data.corr(method='pearson' ) 
print(correlations)
correlations
# Out:
#                               Unnamed: 0  Clump Thickness  Uniformity of Cell Size  \
# Unnamed: 0                         1.000            0.080                    0.091
# Clump Thickness                    0.080            1.000                    0.682
# Uniformity of Cell Size            0.091            0.682                    1.000
# Uniformity of Cell Shape           0.115            0.697                    0.915
# Marginal Adhesion                  0.100            0.473                    0.627
# Single Epithelial  Cell Size       0.002            0.498                    0.707
# Bare Nuclei                        0.164            0.572                    0.642
# Bland Chromatin                    0.073            0.534                    0.660
# Normal Nucleoli                    0.104            0.527                    0.681
# Mitoses                            0.017            0.370                    0.429
# Target                             0.057            0.734                    0.766
#
#                               Uniformity of Cell Shape  Marginal Adhesion    \
# Unnamed: 0                                       0.115                0.100
# Clump Thickness                                  0.697                0.473
# Uniformity of Cell Size                          0.915                0.627
# Uniformity of Cell Shape                         1.000                0.604
# Marginal Adhesion                                0.604                1.000
# Single Epithelial  Cell Size                     0.686                0.510
# Bare Nuclei                                      0.681                0.638
# Bland Chromatin                                  0.640                0.581
# Normal Nucleoli                                  0.705                0.584
# Mitoses                                          0.412                0.399
# Target                                           0.794                0.634
#
#                               Single Epithelial  Cell Size  Bare Nuclei  Bland Chromatin  \
# Unnamed: 0                                           0.002        0.164            0.073
# Clump Thickness                                      0.498        0.572            0.534
# Uniformity of Cell Size                              0.707        0.642            0.660
# Uniformity of Cell Shape                             0.686        0.681            0.640
# Marginal Adhesion                                    0.510        0.638            0.581
# Single Epithelial  Cell Size                         1.000        0.556            0.524
# Bare Nuclei                                          0.556        1.000            0.580
# Bland Chromatin                                      0.524        0.580            1.000
# Normal Nucleoli                                      0.586        0.563            0.607
# Mitoses                                              0.425        0.301            0.276
# Target                                               0.645        0.783            0.644
#
#                               Normal Nucleoli  Mitoses  Target
# Unnamed: 0                              0.104    0.017   0.057
# Clump Thickness                         0.527    0.370   0.734
# Uniformity of Cell Size                 0.681    0.429   0.766
# Uniformity of Cell Shape                0.705    0.412   0.794
# Marginal Adhesion                       0.584    0.399   0.634
# Single Epithelial  Cell Size            0.586    0.425   0.645
# Bare Nuclei                             0.563    0.301   0.783
# Bland Chromatin                         0.607    0.276   0.644
# Normal Nucleoli                         1.000    0.396   0.675
# Mitoses                                 0.396    1.000   0.417
# Target                                  0.675    0.417   1.000
#                               Unnamed: 0  Clump Thickness  Uniformity of Cell Size  \
# Unnamed: 0                         1.000            0.080                    0.091
# Clump Thickness                    0.080            1.000                    0.682
# Uniformity of Cell Size            0.091            0.682                    1.000
# Uniformity of Cell Shape           0.115            0.697                    0.915
# Marginal Adhesion                  0.100            0.473                    0.627
# Single Epithelial  Cell Size       0.002            0.498                    0.707
# Bare Nuclei                        0.164            0.572                    0.642
# Bland Chromatin                    0.073            0.534                    0.660
# Normal Nucleoli                    0.104            0.527                    0.681
# Mitoses                            0.017            0.370                    0.429
# Target                             0.057            0.734                    0.766
#
#                               Uniformity of Cell Shape  Marginal Adhesion    \
# Unnamed: 0                                       0.115                0.100
# Clump Thickness                                  0.697                0.473
# Uniformity of Cell Size                          0.915                0.627
# Uniformity of Cell Shape                         1.000                0.604
# Marginal Adhesion                                0.604                1.000
# Single Epithelial  Cell Size                     0.686                0.510
# Bare Nuclei                                      0.681                0.638
# Bland Chromatin                                  0.640                0.581
# Normal Nucleoli                                  0.705                0.584
# Mitoses                                          0.412                0.399
# Target                                           0.794                0.634
#
#                               Single Epithelial  Cell Size  Bare Nuclei  Bland Chromatin  \
# Unnamed: 0                                           0.002        0.164            0.073
# Clump Thickness                                      0.498        0.572            0.534
# Uniformity of Cell Size                              0.707        0.642            0.660
# Uniformity of Cell Shape                             0.686        0.681            0.640
# Marginal Adhesion                                    0.510        0.638            0.581
# Single Epithelial  Cell Size                         1.000        0.556            0.524
# Bare Nuclei                                          0.556        1.000            0.580
# Bland Chromatin                                      0.524        0.580            1.000
# Normal Nucleoli                                      0.586        0.563            0.607
# Mitoses                                              0.425        0.301            0.276
# Target                                               0.645        0.783            0.644
#
#                               Normal Nucleoli  Mitoses  Target
# Unnamed: 0                              0.104    0.017   0.057
# Clump Thickness                         0.527    0.370   0.734
# Uniformity of Cell Size                 0.681    0.429   0.766
# Uniformity of Cell Shape                0.705    0.412   0.794
# Marginal Adhesion                       0.584    0.399   0.634
# Single Epithelial  Cell Size            0.586    0.425   0.645
# Bare Nuclei                             0.563    0.301   0.783
# Bland Chromatin                         0.607    0.276   0.644
# Normal Nucleoli                         1.000    0.396   0.675
# Mitoses                                 0.396    1.000   0.417
# Target                                  0.675    0.417   1.000

# %%
# Skew for each attribute 
from pandas import read_csv 
filename = "breast_cancer_data.csv" 
#names = ['Batch', 'Eng7', 'Eng8', 'Math7', 'Math8', 'Math9', 'ClassTarget'] 
data = read_csv(filename) 
skew = data.skew() 
print(skew)
# Out:
# Unnamed: 0                      0.000
# Clump Thickness                 0.334
# Uniformity of Cell Size         0.969
# Uniformity of Cell Shape        0.799
# Marginal Adhesion               1.353
# Single Epithelial  Cell Size    1.289
# Bare Nuclei                     0.579
# Bland Chromatin                 0.862
# Normal Nucleoli                 0.961
# Mitoses                         2.757
# Target                          0.175
# dtype: float64

# %%
# Univariate Histograms 
from matplotlib import pyplot 
from pandas import read_csv 
filename = 'breast_cancer_data.csv' 
#names = ['Batch', 'Eng7', 'Eng8', 'Math7', 'Math8', 'Math9', 'ClassTarget'] 
data = read_csv(filename) 
data.hist() 
pyplot.tight_layout()
pyplot.show()

# %%
# Correlation Matrix Plot 
from matplotlib import pyplot 
from pandas import read_csv 
import numpy 
filename = 'breast_cancer_data.csv' 
#names = ['preg', 'plas', 'pres', 'skin', 'test', 'mass', 'pedi', 'age', 'class'] 
data = read_csv(filename) 
correlations = data.corr() 

# plot correlation matrix 
fig = pyplot.figure() 
ax = fig.add_subplot(111) 
cax = ax.matshow(correlations, vmin=-1, vmax=1) 
fig.colorbar(cax) 
ticks = numpy.arange(0,9,1) 
ax.set_xticks(ticks) 
ax.set_yticks(ticks) 
ax.set_xticklabels(names) 
ax.set_yticklabels(names) 
pyplot.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-11-41c2188bbada> in <module>()
#      16 ax.set_xticks(ticks)
#      17 ax.set_yticks(ticks)
# ---> 18 ax.set_xticklabels(names)
#      19 ax.set_yticklabels(names)
#      20 pyplot.show()
#
# NameError: name 'names' is not defined

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
df=pd.read_csv('breast_cancer_data.csv')
plt.figure(figsize=(10,5))
sns.heatmap(df.corr())

# %%
# Rescale data (between 0 and 1) 
from pandas import read_csv 
from numpy import set_printoptions 
from sklearn.preprocessing import MinMaxScaler 
filename = 'breast_cancer_data.csv' 
#names = ['preg' , 'plas' , 'pres' , 'skin' , 'test' , 'mass' , 'pedi' , 'age' , 'class'] 
dataframe = read_csv(filename) 
dataframe.isnull().sum()
dataframe = dataframe.dropna()
dataframe.isnull().sum() 
array = dataframe.values 

# separate array into input and output components 
X = array[:,0:8] 
Y = array[:,8] 
scaler = MinMaxScaler(feature_range=(0, 1)) 
rescaledX = scaler.fit_transform(X) 

# summarize transformed data 
set_printoptions(precision=3)
print(rescaledX[0:5,:])
# Out:
# [[0.    0.444 0.    0.    0.    0.111 0.    0.222]
#  [0.003 0.444 0.333 0.333 0.444 0.667 1.    0.222]
#  [0.007 0.222 0.    0.    0.    0.111 0.111 0.222]
#  [0.01  0.556 0.778 0.778 0.    0.222 0.333 0.222]
#  [0.013 0.333 0.    0.    0.222 0.111 0.    0.222]]
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:475: DataConversionWarning: Data with input dtype int64 was converted to float64 by MinMaxScaler.
#   warnings.warn(msg, DataConversionWarning)

# %%
# Compare Algorithms 
from pandas import read_csv 
from matplotlib import pyplot 
from sklearn.model_selection import KFold 
from sklearn.model_selection import cross_val_score 
from sklearn.linear_model import LogisticRegression 
from sklearn.tree import DecisionTreeClassifier 
from sklearn.neighbors import KNeighborsClassifier 
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis 
from sklearn.naive_bayes import GaussianNB 
from sklearn.svm import SVC 

# load dataset 
filename = 'breast_cancer_data.csv' 
#names = ['preg' , 'plas' , 'pres' , 'skin' , 'test' , 'mass' , 'pedi' , 'age' , 'class'] 
dataframe = read_csv(filename)
dataframe.isnull().sum()
dataframe2 = dataframe.dropna(how='any')
dataframe2.head()
dataframe2 = dataframe2.drop(columns=[ 'Unnamed: 0'])
array = dataframe2.values 
X = array[:,0:10] 
Y = array[:,-1] 

# prepare models 
models = [] 
models.append((' LR' , LogisticRegression())) 
models.append((' LDA' , LinearDiscriminantAnalysis())) 
models.append((' KNN' , KNeighborsClassifier())) 
models.append((' CART' , DecisionTreeClassifier())) 
models.append((' NB' , GaussianNB())) 
models.append((' SVM' , SVC()))

# evaluate each model in turn 
results = [] 
names = [] 
scoring = 'accuracy' 
for name, model in models: 
    kfold = KFold(n_splits=10, random_state=7) 
    cv_results = cross_val_score(model, rescaledX, Y, cv=kfold, scoring=scoring) 
    results.append(cv_results)
    names.append(name) 
    msg = "%s: %f (%f)" % (name, cv_results.mean(), cv_results.std()) 
    print(msg)
# boxplot algorithm comparison 
fig = pyplot.figure() 
fig.suptitle('Algorithm Comparison') 
ax = fig.add_subplot(111) 
pyplot.boxplot(results) 
ax.set_xticklabels(names)
pyplot.show()
# Out:
#  LR: 0.950000 (0.034157)
#  LDA: 0.936667 (0.040689)
#  KNN: 0.966667 (0.029814)
#  CART: 0.920000 (0.056174)
#  NB: 0.943333 (0.036667)
#  SVM: 0.946667 (0.040000)

# %%
# Feature Extraction with PCA 
from pandas import read_csv 
from sklearn.decomposition import PCA 

# load data 
filename = 'breast_cancer_data.csv' 
#names = ['preg' , 'plas' , 'pres' , 'skin' , 'test' , 'mass' , 'pedi' , 'age' , 'class']

dataframe = read_csv(filename) 
array = dataframe.values 
X = array[:,0:10] 
Y = array[:,-1] 

# feature extraction 
pca = PCA(n_components=3) 
fit = pca.fit(X) 

# summarize components 
print("Explained Variance: %s" % fit.explained_variance_ratio_) 
print(fit.components_)
# pd.DataFrame(fit.components_[0].reshape(1, 8).tolist(), columns=names[:-1]).T.sort_values(0, ascending=False)
# Out:
# Explained Variance: [9.898e-01 6.645e-03 8.222e-04]
# [[ 9.999e-01  2.881e-03  3.326e-03  4.118e-03  3.422e-03  6.781e-05
#    7.290e-03  1.846e-03  3.963e-03  4.190e-04]
#  [-1.015e-02  3.347e-01  3.979e-01  3.945e-01  3.133e-01  2.726e-01
#    4.406e-01  2.258e-01  3.694e-01  1.411e-01]
#  [ 3.079e-03  2.108e-01  2.683e-01  2.213e-01 -2.804e-01  1.480e-01
#   -7.876e-01 -3.976e-03  2.861e-01  1.786e-01]]

# %%
# Compare Algorithms 
from pandas import read_csv 
from matplotlib import pyplot 
from sklearn.model_selection import KFold 
from sklearn.model_selection import cross_val_score 
from sklearn.linear_model import LogisticRegression 
from sklearn.tree import DecisionTreeClassifier 
from sklearn.neighbors import KNeighborsClassifier 
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis 
from sklearn.naive_bayes import GaussianNB 
from sklearn.svm import SVC 

# load dataset 
filename = 'breast_cancer_data.csv' 
#names = ['preg' , 'plas' , 'pres' , 'skin' , 'test' , 'mass' , 'pedi' , 'age' , 'class'] 
dataframe = read_csv(filename)
dataframe.isnull().sum()
dataframe2 = dataframe.dropna(how='any')
dataframe2.head()
dataframe2 = dataframe2.drop(columns=[ 'Unnamed: 0'])
array = dataframe2.values 
X = array[:,0:10] 
Y = array[:,-1] 

# prepare models 
models = [] 
models.append((' LR' , LogisticRegression())) 
models.append((' LDA' , LinearDiscriminantAnalysis())) 
models.append((' KNN' , KNeighborsClassifier())) 
models.append((' CART' , DecisionTreeClassifier())) 
models.append((' NB' , GaussianNB())) 
models.append((' SVM' , SVC()))

# evaluate each model in turn 
results = [] 
names = [] 
scoring = 'accuracy' 
for name, model in models: 
    kfold = KFold(n_splits=15, random_state=9) 
    cv_results = cross_val_score(model, rescaledX, Y, cv=kfold, scoring=scoring) 
    results.append(cv_results)
    names.append(name) 
    msg = "%s: %f (%f)" % (name, cv_results.mean(), cv_results.std()) 
    print(msg)
# boxplot algorithm comparison 
fig = pyplot.figure() 
fig.suptitle('Algorithm Comparison') 
ax = fig.add_subplot(111) 
pyplot.boxplot(results) 
ax.set_xticklabels(names)
pyplot.show()
# Out:
#  LR: 0.950000 (0.051640)
#  LDA: 0.940000 (0.063770)
#  KNN: 0.963333 (0.046428)
#  CART: 0.906667 (0.081377)
#  NB: 0.943333 (0.051208)
#  SVM: 0.943333 (0.060185)

# %%
# Create a pipeline that standardizes the data then creates a model 
from pandas import read_csv 
from sklearn.model_selection import KFold 
from sklearn.model_selection import cross_val_score 
from sklearn.preprocessing import StandardScaler 
from sklearn.pipeline import Pipeline 
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis 

# load data 
filename = 'breast_cancer_data.csv' 
#names = ['preg' , 'plas' , 'pres' , 'skin' , 'test' , 'mass' , 'pedi' , 'age' , 'class'] 
dataframe = read_csv(filename) 
dataframe.isnull().sum()
dataframe2 = dataframe.dropna(how='any')
dataframe2.head()
dataframe2 = dataframe2.drop(columns=[ 'Unnamed: 0'])
array = dataframe2.values 
X = array[:,0:9] 
Y = array[:,-1] 

# create pipeline 
estimators = [] 
estimators.append(('standardize' , StandardScaler())) 
estimators.append(('KNN' , KNeighborsClassifier())) 
model = Pipeline(estimators) 

# evaluate pipeline 
kfold = KFold(n_splits=13, random_state=10) 
results = cross_val_score(model, X, Y, cv=kfold) 
print(results.mean())
# Out:
# 0.9569397993311038
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:475: DataConversionWarning: Data with input dtype int64 was converted to float64 by StandardScaler.
#   warnings.warn(msg, DataConversionWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:475: DataConversionWarning: Data with input dtype int64 was converted to float64 by StandardScaler.
#   warnings.warn(msg, DataConversionWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:475: DataConversionWarning: Data with input dtype int64 was converted to float64 by StandardScaler.
#   warnings.warn(msg, DataConversionWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:475: DataConversionWarning: Data with input dtype int64 was converted to float64 by StandardScaler.
#   warnings.warn(msg, DataConversionWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:475: DataConversionWarning: Data with input dtype int64 was converted to float64 by StandardScaler.
#   warnings.warn(msg, DataConversionWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:475: DataConversionWarning: Data with input dtype int64 was converted to float64 by StandardScaler.
#   warnings.warn(msg, DataConversionWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:475: DataConversionWarning: Data with input dtype int64 was converted to float64 by StandardScaler.
#   warnings.warn(msg, DataConversionWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:475: DataConversionWarning: Data with input dtype int64 was converted to float64 by StandardScaler.
#   warnings.warn(msg, DataConversionWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:475: DataConversionWarning: Data with input dtype int64 was converted to float64 by StandardScaler.
#   warnings.warn(msg, DataConversionWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:475: DataConversionWarning: Data with input dtype int64 was converted to float64 by StandardScaler.
#   warnings.warn(msg, DataConversionWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:475: DataConversionWarning: Data with input dtype int64 was converted to float64 by StandardScaler.
#   warnings.warn(msg, DataConversionWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:475: DataConversionWarning: Data with input dtype int64 was converted to float64 by StandardScaler.
#   warnings.warn(msg, DataConversionWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:475: DataConversionWarning: Data with input dtype int64 was converted to float64 by StandardScaler.
#   warnings.warn(msg, DataConversionWarning)

# %%
# Compare Algorithms 
from pandas import read_csv 
from matplotlib import pyplot 
from sklearn.model_selection import KFold 
from sklearn.model_selection import cross_val_score 
from sklearn.linear_model import LogisticRegression 
from sklearn.tree import DecisionTreeClassifier 
from sklearn.neighbors import KNeighborsClassifier 
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis 
from sklearn.naive_bayes import GaussianNB 
from sklearn.svm import SVC 

# load dataset 
filename = 'breast_cancer_data.csv' 
#names = ['preg' , 'plas' , 'pres' , 'skin' , 'test' , 'mass' , 'pedi' , 'age' , 'class'] 
dataframe = read_csv(filename)
dataframe.isnull().sum()
dataframe2 = dataframe.dropna(how='any')
dataframe2.head()
dataframe2 = dataframe2.drop(columns=[ 'Unnamed: 0'])
array = dataframe2.values 
X = array[:,0:9] 
Y = array[:,-1] 

# prepare models 
models = [] 
models.append((' LR' , LogisticRegression())) 
models.append((' LDA' , LinearDiscriminantAnalysis())) 
models.append((' KNN' , KNeighborsClassifier())) 
models.append((' CART' , DecisionTreeClassifier())) 
models.append((' NB' , GaussianNB())) 
models.append((' SVM' , SVC()))

# evaluate each model in turn 
results = [] 
names = [] 
scoring = 'accuracy' 
for name, model in models: 
    kfold = KFold(n_splits=10, random_state=16) 
    cv_results = cross_val_score(model, rescaledX, Y, cv=kfold, scoring=scoring) 
    results.append(cv_results)
    names.append(name) 
    msg = "%s: %f (%f)" % (name, cv_results.mean(), cv_results.std()) 
    print(msg)
# boxplot algorithm comparison 
fig = pyplot.figure() 
fig.suptitle('Algorithm Comparison') 
ax = fig.add_subplot(111) 
pyplot.boxplot(results) 
ax.set_xticklabels(names)
pyplot.show()
# Out:
#  LR: 0.950000 (0.034157)
#  LDA: 0.936667 (0.040689)
#  KNN: 0.966667 (0.029814)
#  CART: 0.910000 (0.085700)
#  NB: 0.943333 (0.036667)
#  SVM: 0.946667 (0.040000)

# %%
# Create a pipeline that standardizes the data then creates a model 
from pandas import read_csv 
from sklearn.model_selection import KFold 
from sklearn.model_selection import cross_val_score 
from sklearn.preprocessing import StandardScaler 
from sklearn.pipeline import Pipeline 
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis 

# load data 
filename = 'breast_cancer_data.csv' 
#names = ['preg' , 'plas' , 'pres' , 'skin' , 'test' , 'mass' , 'pedi' , 'age' , 'class'] 
dataframe = read_csv(filename) 
dataframe.isnull().sum()
dataframe2 = dataframe.dropna(how='any')
dataframe2.head()
dataframe2 = dataframe2.drop(columns=[ 'Unnamed: 0'])
array = dataframe2.values 
X = array[:,0:9] 
Y = array[:,-1] 

# create pipeline 
estimators = [] 
estimators.append(('standardize' , StandardScaler())) 
estimators.append(('LR' , LogisticRegression())) 
model = Pipeline(estimators) 

# evaluate pipeline 
kfold = KFold(n_splits=15, random_state=25) 
results = cross_val_score(model, X, Y, cv=kfold) 
print(results.mean())
# Out:
# 0.9499999999999998
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:475: DataConversionWarning: Data with input dtype int64 was converted to float64 by StandardScaler.
#   warnings.warn(msg, DataConversionWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:475: DataConversionWarning: Data with input dtype int64 was converted to float64 by StandardScaler.
#   warnings.warn(msg, DataConversionWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:475: DataConversionWarning: Data with input dtype int64 was converted to float64 by StandardScaler.
#   warnings.warn(msg, DataConversionWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:475: DataConversionWarning: Data with input dtype int64 was converted to float64 by StandardScaler.
#   warnings.warn(msg, DataConversionWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:475: DataConversionWarning: Data with input dtype int64 was converted to float64 by StandardScaler.
#   warnings.warn(msg, DataConversionWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:475: DataConversionWarning: Data with input dtype int64 was converted to float64 by StandardScaler.
#   warnings.warn(msg, DataConversionWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:475: DataConversionWarning: Data with input dtype int64 was converted to float64 by StandardScaler.
#   warnings.warn(msg, DataConversionWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:475: DataConversionWarning: Data with input dtype int64 was converted to float64 by StandardScaler.
#   warnings.warn(msg, DataConversionWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:475: DataConversionWarning: Data with input dtype int64 was converted to float64 by StandardScaler.
#   warnings.warn(msg, DataConversionWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:475: DataConversionWarning: Data with input dtype int64 was converted to float64 by StandardScaler.
#   warnings.warn(msg, DataConversionWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:475: DataConversionWarning: Data with input dtype int64 was converted to float64 by StandardScaler.
#   warnings.warn(msg, DataConversionWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:475: DataConversionWarning: Data with input dtype int64 was converted to float64 by StandardScaler.
#   warnings.warn(msg, DataConversionWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:475: DataConversionWarning: Data with input dtype int64 was converted to float64 by StandardScaler.
#   warnings.warn(msg, DataConversionWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:475: DataConversionWarning: Data with input dtype int64 was converted to float64 by StandardScaler.
#   warnings.warn(msg, DataConversionWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:475: DataConversionWarning: Data with input dtype int64 was converted to float64 by StandardScaler.
#   warnings.warn(msg, DataConversionWarning)
